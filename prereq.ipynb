# %% [markdown]
# # Prework. Get set up before Day 1
#
# Twenty minutes, self-paced. This gets your browser notebook working and downloads the one model
# Day 1 needs, so no live minute goes on setup. Do it a day or two ahead. If a cell fails, note the
# error and bring it to the session.
#
# You need no Manifesto Project account yet. We set the key up together at the end of Day 1, with an
# instructor watching, so anything that breaks gets fixed in the room.

# %% [markdown]
# ## 1. Open in Colab and pick a runtime
#
# This runs in Google Colab, a free notebook in your browser. Sign in with a Google account. For
# Days 1 and 2 the free CPU runtime is enough. For Day 3 you switch to a free GPU with Runtime,
# then Change runtime type, then T4 GPU. Try that toggle now so you know where it lives.

# %%
import sys
print('Python', sys.version.split()[0])
print('If you can read this, your runtime works.')

# %% [markdown]
# ## 2. Read your first error
#
# Errors are normal and readable. Run the cell below, then read the last line first, because that is
# the line naming the problem.

# %%
try:
    1 / 0
except ZeroDivisionError as e:
    print('ZeroDivisionError:', e)
    print('The last line names the problem. Start there, every time.')

# %% [markdown]
# ## 3. Download the embedding model once
#
# Day 1 matches messy country names by meaning using a small sentence model. Pull it now so the
# first run in the session is instant. This works on the free CPU runtime and takes a minute or two
# on a slow connection.

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
vec = model.encode(['a test sentence'])
print('Model ready. Embedding size', vec.shape[1])

# %% [markdown]
# ## 4. Check pandas is there
#
# pandas is the table library we live in from Day 1 onward. Colab ships with it, so this cell just
# confirms it imports.

# %%
import pandas as pd

df = pd.DataFrame({'party': ['Labour', 'Conservative'], 'seats': [412, 121]})
print('pandas', pd.__version__)
df

# %% [markdown]
# ## You are ready
#
# If every cell above ran, you are set. Bring any error message you hit and we will look at it
# together.
#
# See you on Day 1.
